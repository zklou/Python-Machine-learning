# %%
import joblib
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

penguins_size = pd.read_csv('/Users/zklou/4404/4404A1/penguins_size.csv')

species_num = {'Adelie': 1, 'Chinstrap': 2, 'Gentoo': 3,}
penguins_size['species'] = penguins_size['species'].map(species_num)

tr_labels = penguins_size.species
tr_features = penguins_size.culmen_length_mm, penguins_size.culmen_depth_mm, penguins_size.flipper_length_mm, penguins_size.body_mass_g,

data = np.array(penguins_size)
data[:10,:]

x,y = np.split(data, (4,), axis = 1)  
x_train, x_test, y_train,y_test = train_test_split(x,y,train_size = 0.6, test_size = 0.2,random_state = 0)

from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000)

print(y_train)
# Out:
# [[191.0 4150.0 'MALE']
#  [218.0 4950.0 'FEMALE']
#  [215.0 5500.0 'MALE']
#  [176.0 3450.0 'FEMALE']
#  [201.0 4050.0 'MALE']
#  [218.0 5300.0 'MALE']
#  [202.0 3550.0 'FEMALE']
#  [189.0 3800.0 'FEMALE']
#  [214.0 4650.0 'FEMALE']
#  [193.0 3800.0 'FEMALE']
#  [197.0 3300.0 'MALE']
#  [195.0 3350.0 'FEMALE']
#  [191.0 3400.0 'MALE']
#  [182.0 3200.0 'FEMALE']
#  [199.0 3750.0 'FEMALE']
#  [193.0 3400.0 'FEMALE']
#  [208.0 4450.0 'FEMALE']
#  [197.0 4500.0 'MALE']
#  [212.0 4875.0 'FEMALE']
#  [197.0 4275.0 'MALE']
#  [191.0 3175.0 'FEMALE']
#  [213.0 5100.0 'FEMALE']
#  [213.0 4650.0 'FEMALE']
#  [190.0 3900.0 'MALE']
#  [195.0 3300.0 'FEMALE']
#  [219.0 4700.0 'FEMALE']
#  [208.0 4575.0 'FEMALE']
#  [197.0 3750.0 'MALE']
#  [214.0 4400.0 'FEMALE']
#  [187.0 3425.0 'FEMALE']
#  [196.0 4700.0 'MALE']
#  [186.0 3800.0 'FEMALE']
#  [187.0 3150.0 'FEMALE']
#  [193.0 3475.0 nan]
#  [224.0 5650.0 'MALE']
#  [198.0 3775.0 'FEMALE']
#  [220.0 5300.0 'MALE']
#  [210.0 4200.0 'FEMALE']
# ...

# %%
import joblib
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

penguins_size = pd.read_csv('/Users/zklou/4404/4404A1/penguins_size.csv')

penguins_size = pd.DataFrame.dropna(penguins_size)
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
# 在训练集上训练逻辑回归模型
clf.fit(x_train, y_train)
## 查看其对应的w
print('the weight of Logistic Regression:',clf.coef_)
## 查看其对应的w0
print('the intercept(w0) of Logistic Regression:',clf.intercept_)
## 在训练集和测试集上分布利用训练好的模型进行预测
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bt/cm71ndhn74l6gqyq_sqtf5xm0000gn/T/ipykernel_939/3904353261.py in <module>
#       1 # 在训练集上训练逻辑回归模型
# ----> 2 clf.fit(x_train, y_train)
#       3 ## 查看其对应的w
#       4 print('the weight of Logistic Regression:',clf.coef_)
#       5 ## 查看其对应的w0
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
